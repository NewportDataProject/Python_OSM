# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
print(ox.__version__)
print(nx.__version__)
# Out:
# 0.6
# 2.0

# %%
city = ox.gdf_from_place('Newport, RI')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<matplotlib.figure.Figure at 0x212f473ea58>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x212f4759080>)

# %%
streets = ox.graph_from_place('Newport, RI')
ox.plot_graph(streets, fig_height=16)
# Out:
# (<matplotlib.figure.Figure at 0x212f78d13c8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x212f0f345f8>)

# %%
btwn_streets = nx.betweenness_centrality(streets)
max(btwn_streets.values())
# Out:
# 0.3366120612948134
